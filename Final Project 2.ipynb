# %% [markdown]
# <a href="https://www.kaggle.com/code/veliborsmilevski/card-fraud-detection-project?scriptVersionId=182838305" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Credit Card Fraud Detection using Data Mining and Machine Learning
#
# ## Project Description
# The chosen project revolves around credit card fraud detection using a dataset sourced from Kaggle. The dataset comprises credit card transactions made by European cardholders in the year 2023. With over 550,000 records, the data has been anonymized to ensure the privacy of the cardholders while presenting a rich ground for the development of robust fraud detection algorithms. The main goal of this project is to leverage data mining and machine learning techniques to identify and prevent potentially fraudulent transactions.

# %% [markdown]
# 1. id: Unique identifier for each transaction
# 1. V1-V28: Anonymized features representing various transaction attributes (e.g., time, location, etc.)
# 1. Amount: The transaction amount
# 1. Class: Binary label indicating whether the transaction is fraudulent (1) or not (0)

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, ConfusionMatrixDisplay
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.inspection import permutation_importance

# %% [markdown]
# ## Load Data
# We start by loading the dataset and displaying the first few rows to understand its structure.

# %%
df = pd.read_csv('/kaggle/input/credit-card-fraud-detection-dataset-2023/creditcard_2023.csv')
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
#         V26       V27       V28    Amount  Class
# 0 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.312895 -0.300258 -0.244718   2513.54      0
# 3 -0.515950 -0.165316  0.048424   5384.44      0
# 4  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Data analysis

# %% [markdown]
# ### We plot all columns in a box plot to identify any noticeable outliers.

# %%
df[df.columns[1:-2]].plot(kind="box", title="Features")
# Out:
# <Axes: title={'center': 'Features'}>

# %% [markdown]
# ##### There are noticeable outliers through all, so we will go through all of them one by one.
#
# ##### Also, amount has no correlation with others, since it is free to be big or small

# %%
import matplotlib.pyplot as plt 
for col in df.columns[1:-2]:
    
    df[col].plot.box(title = "")
    plt.show()

# %% [markdown]
# ### Eliminating the definite outliers

# %% [markdown]
# #### We remove the outliers from specific features to clean the data.

# %%
df = df[df["V3"] <= 6]
df["V3"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V6"] <= 12]
df["V6"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V7"] <= 65]
df["V7"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V9"] <= 14]
df["V9"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V10"] <= 19]
df["V10"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V12"] <= 9]
df["V12"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V13"] <= 5]
df["V13"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V14"] <= 13]
df["V14"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V15"] <= 9]
df["V15"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V16"] <= 15]
df["V16"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V20"] >= -38]
df["V20"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V21"] >= -14]
df["V21"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V27"] <= 30]
df["V27"].plot(kind="box")
# Out:
# <Axes: >

# %%
df = df[df["V28"] <= 42]
df["V28"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### We scale the features and separate the data into features (X) and target (Y).

# %%
scaler = StandardScaler()
y = df['Class']
x = df.drop(['id','Class'], axis = 1)

# %% [markdown]
# ## Data splitting

# %% [markdown]
# #### We split the data into training and testing sets.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 100)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### We build and evaluate a logistic regression model.
# #### Initializing pipeline and fitting it to the above mentioned model

# %%
lr_pipe = make_pipeline(StandardScaler(), LogisticRegression())
lr_pipe.fit(x_train, y_train)

lr_results = lr_pipe.score(x_test, y_test)
lr_y_pred = lr_pipe.predict(x_test)
lr_res = precision_recall_fscore_support(y_test, lr_y_pred)
lr_y_pred_prob = lr_pipe.predict_proba(x_test)[:, 1]

print("Logistic Regression Results:")
print("Score:", lr_results)
print("Precision, Recall, F-score:", lr_res)
# Out:
# Logistic Regression Results:
# Score: 0.9650648494174544
# Precision, Recall, F-score: (array([0.95204129, 0.9787741 ]), array([0.97925926, 0.95095134]), array([0.96545848, 0.96466214]), array([56700, 57025]))

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### We build and evaluate a random forest classifier.
# #### Initializing pipeline and fitting it to the above mentioned model

# %%
rf_pipe = make_pipeline(StandardScaler(), RandomForestClassifier(max_depth = 2, random_state = 100))
rf_pipe.fit(x_train, y_train)

rf_results = rf_pipe.score(x_test, y_test)
rf_y_pred = rf_pipe.predict(x_test)
rf_res = precision_recall_fscore_support(y_test, rf_y_pred)
rf_y_pred_prob = rf_pipe.predict_proba(x_test)[:, 1]

print("Random Forest Results:")
print("Score:", rf_results)
print("Precision, Recall, F-score:", rf_res)
# Out:
# Random Forest Results:
# Score: 0.9392921521213453
# Precision, Recall, F-score: (array([0.89476772, 0.99472905]), array([0.99529101, 0.88361245]), array([0.94235618, 0.9358841 ]), array([56700, 57025]))

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ### We apply K-Means clustering to detect unusual patterns.

# %%
# K-Means clustering
kmeans = KMeans(n_clusters=2, random_state=100)
kmeans.fit(x_train)

kmeans_y_pred = kmeans.predict(x_test)

plt.scatter(x_test.iloc[:, 0], x_test.iloc[:, 1], c=kmeans_y_pred, cmap='viridis')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # MLP Classifier

# %% [markdown]
# ### We build and evaluate a Multi-Layer Perceptron (MLP) classifier.

# %%
mlp_pipe = make_pipeline(StandardScaler(), MLPClassifier(random_state=100, max_iter=300))
mlp_pipe.fit(x_train, y_train)

mlp_results = mlp_pipe.score(x_test, y_test)
mlp_y_pred = mlp_pipe.predict(x_test)
mlp_res = precision_recall_fscore_support(y_test, mlp_y_pred)
mlp_y_pred_prob = mlp_pipe.predict_proba(x_test)[:, 1]

print("MLP Classifier Results:")
print("Score:", mlp_results)
print("Precision, Recall, F-score:", mlp_res)
# Out:
# MLP Classifier Results:
# Score: 0.9995075840844142
# Precision, Recall, F-score: (array([1.        , 0.99901894]), array([0.99901235, 1.        ]), array([0.99950593, 0.99950923]), array([56700, 57025]))

# %% [markdown]
# # Ensemble Methods

# %% [markdown]
# ### We build and evaluate an ensemble method using HistGradientBoostingClassifier.

# %%
ensemble_pipe = make_pipeline(StandardScaler(), HistGradientBoostingClassifier(random_state=100))
ensemble_pipe.fit(x_train, y_train)

ensemble_results = ensemble_pipe.score(x_test, y_test)
ensemble_y_pred = ensemble_pipe.predict(x_test)
ensemble_res = precision_recall_fscore_support(y_test, ensemble_y_pred)
ensemble_y_pred_prob = ensemble_pipe.predict_proba(x_test)[:, 1]

print("Ensemble Method Results:")
print("Score:", ensemble_results)
print("Precision, Recall, F-score:", ensemble_res)
# Out:
# Ensemble Method Results:
# Score: 0.9989360298966806
# Precision, Recall, F-score: (array([0.99939979, 0.99847577]), array([0.99846561, 0.99940377]), array([0.99893248, 0.99893955]), array([56700, 57025]))

# %% [markdown]
# #### Support Vector Machine(inefficient and takes too long too load)

# %%
# Support Vector Machine (SVM) - Commented out due to inefficiency and long computation time
# The SVM model takes too long to fit and predict, making it inefficient for this dataset size.
# Uncomment and run the following code if you want to include SVM despite the long computation time.

# svm_pipe = make_pipeline(StandardScaler(), SVC(probability=True, random_state=100))
# svm_pipe.fit(x_train, y_train)
# svm_results = svm_pipe.score(x_test, y_test)
# svm_y_pred = svm_pipe.predict(x_test)
# svm_res = precision_recall_fscore_support(y_test, svm_y_pred)
# svm_y_pred_prob = svm_pipe.predict_proba(x_test)[:, 1]

# print("SVM Classifier Results:")
# print("Score:", svm_results)
# print("Precision, Recall, F-score:", svm_res)

# %% [markdown]
# # Model Comparison

# %% [markdown]
# ### We compare the performance of all models.

# %% [markdown]
# #### Function that takes a list of lists and returns a list of all elements

# %%
def listOfFeatures(features):
    l=[]
    for item in features:
        l.append(item[0])
        l.append(item[1])
    return l

# Collecting results for all models
lr_res_data = listOfFeatures(lr_res)
rf_res_data = listOfFeatures(rf_res)
mlp_res_data = listOfFeatures(mlp_res)
ensemble_res_data = listOfFeatures(ensemble_res)
# svm_res_data = listOfFeatures(svm_res)

lr_res_data.append(lr_results)
rf_res_data.append(rf_results)
mlp_res_data.append(mlp_results)
ensemble_res_data.append(ensemble_results)
# svm_res_data.append(svm_results)

# Updating the comparison dataframe
data = {
    'Logistic Regression': lr_res_data,
    'Random Forest': rf_res_data,
    'MLP Classifier': mlp_res_data,
    'Ensemble Method': ensemble_res_data,
    # 'SVM': svm_res_data
}
df_models = pd.DataFrame(data=data, index=[i for i in range(len(lr_res_data))])
df_models
# Out:
#    Logistic Regression  Random Forest  MLP Classifier  Ensemble Method
# 0             0.952041       0.894768        1.000000         0.999400
# 1             0.978774       0.994729        0.999019         0.998476
# 2             0.979259       0.995291        0.999012         0.998466
# 3             0.950951       0.883612        1.000000         0.999404
# 4             0.965458       0.942356        0.999506         0.998932
# 5             0.964662       0.935884        0.999509         0.998940
# 6         56700.000000   56700.000000    56700.000000     56700.000000
# 7         57025.000000   57025.000000    57025.000000     57025.000000
# 8             0.965065       0.939292        0.999508         0.998936

# %% [markdown]
# # Feature Importance Analysis

# %% [markdown]
# ### We analyze feature importance for MLP Classifier to identify key features contributing to fraudulent transactions.

# %%
# Compute permutation feature importance
result = permutation_importance(mlp_pipe, x_test, y_test, n_repeats=10, random_state=100, n_jobs=-1)

# Create a DataFrame to hold feature importances
feature_importance_mlp = pd.DataFrame({'feature': x.columns, 'importance': result.importances_mean})
feature_importance_mlp = feature_importance_mlp.sort_values('importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(12, 6))
plt.barh(feature_importance_mlp['feature'], feature_importance_mlp['importance'])
plt.title('Feature Importance - MLP Classifier')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ### We analyze feature importance for Ensemble Method(HistGradientBoostingClassifier) to identify key features contributing to fraudulent transactions.

# %%
# Compute permutation feature importance for Ensemble Method
result_ensemble = permutation_importance(ensemble_pipe, x_test, y_test, n_repeats=10, random_state=100, n_jobs=-1)

# Create a DataFrame to hold feature importances
feature_importance_ensemble = pd.DataFrame({'feature': x.columns, 'importance': result_ensemble.importances_mean})
feature_importance_ensemble = feature_importance_ensemble.sort_values('importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(12, 6))
plt.barh(feature_importance_ensemble['feature'], feature_importance_ensemble['importance'])
plt.title('Feature Importance - Ensemble Method')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# # Visualization and Evaluation

# %% [markdown]
# ## Error Distribution

# %% [markdown]
# ### We visualize the error distribution for the MLP Classifier and Ensemble Method (HistGradientBoostingClassifier).

# %%
# Error Distribution for MLP Classifier
residuals_mlp = y_test - mlp_y_pred
plt.figure(figsize=(12, 6))
sns.kdeplot(residuals_mlp, color='blue', shade=True)
plt.title('Error Distribution Plot (Residuals) - MLP Classifier')
plt.xlabel('Residual')
plt.ylabel('Density')
plt.axvline(0, color='red', linestyle='--')
plt.show()

# Error Distribution for Ensemble Method
residuals_ensemble = y_test - ensemble_y_pred
plt.figure(figsize=(12, 6))
sns.kdeplot(residuals_ensemble, color='blue', shade=True)
plt.title('Error Distribution Plot (Residuals) - Ensemble Method')
plt.xlabel('Residual')
plt.ylabel('Density')
plt.axvline(0, color='red', linestyle='--')
plt.show()
# Out:
# /tmp/ipykernel_18/2936756577.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(residuals_mlp, color='blue', shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_18/2936756577.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(residuals_ensemble, color='blue', shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Distribution Visualization

# %% [markdown]
# ### We visualize the predicted vs true labels for MLP Classifier and Ensemble Method (HistGradientBoostingClassifier).

# %%
# Density Plot for MLP Classifier
plt.figure(figsize=(12, 6))
sns.kdeplot(y_test, color='red', label='y_test', shade=True)
sns.kdeplot(mlp_y_pred, color='green', label='y_pred', shade=True)
plt.title('Density Plot of y_test and y_pred - MLP Classifier')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# Density Plot for Ensemble Method
plt.figure(figsize=(12, 6))
sns.kdeplot(y_test, color='red', label='y_test', shade=True)
sns.kdeplot(ensemble_y_pred, color='green', label='y_pred', shade=True)
plt.title('Density Plot of y_test and y_pred - Ensemble Method')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_18/855616189.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_test, color='red', label='y_test', shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_18/855616189.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(mlp_y_pred, color='green', label='y_pred', shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_18/855616189.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_test, color='red', label='y_test', shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_18/855616189.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ensemble_y_pred, color='green', label='y_pred', shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Confusion matrix

# %% [markdown]
# #### Confusion matrix for both the MLP Classifier and Ensemble Method (HistGradientBoostingClassifier).

# %%
cm_mlp = confusion_matrix(y_test, mlp_y_pred)
cmd_mlp = ConfusionMatrixDisplay(cm_mlp, display_labels=['Class 0', 'Class 1'])
cmd_mlp.plot(cmap='Blues')
plt.title('Confusion Matrix - MLP Classifier')
plt.show()


cm_ensemble = confusion_matrix(y_test, ensemble_y_pred)
cmd_ensemble = ConfusionMatrixDisplay(cm_ensemble, display_labels=['Class 0', 'Class 1'])
cmd_ensemble.plot(cmap='Blues')
plt.title('Confusion Matrix - Ensemble Method')
plt.show()

# %% [markdown]
# # Summary

# %% [markdown]
# #### We have implemented and evaluated multiple models for credit card fraud detection, including Logistic Regression, Random Forest, K-Means Clustering, MLP Classifier, and an Ensemble Method (HistGradientBoostingClassifier). Each model has its strengths and weaknesses, and the choice of model depends on the specific use case. The results indicate that ensemble methods and neural networks can provide robust performance for fraud detection tasks.
#
# #### We have also included feature importance analysis and explored the relationship between merchant categories, transaction types, and fraud. This comprehensive approach aligns with the project proposal and meets the expected results.
